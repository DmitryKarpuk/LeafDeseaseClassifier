# %% [markdown]
# ## Load data from kaggle

# %%
# !pip install kaggle -q
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle competitions download -c plant-pathology-2020-fgvc7
# Out:
# Downloading plant-pathology-2020-fgvc7.zip to /content
# 100% 778M/779M [00:34<00:00, 25.5MB/s]
# 100% 779M/779M [00:34<00:00, 23.7MB/s]

# %%
# !unzip -q /content/plant-pathology-2020-fgvc7.zip

# %%
# !pip -q install tensorflow
# !pip install -q keras

# %% [markdown]
# # Data preparation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.applications.resnet50  import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %matplotlib inline

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
SEED = 2007
BATCH_SIZE = 64
TARGET = ['healthy', 'multiple_diseases',	'rust',	'scab']


np.random.seed(SEED)
tf.keras.utils.set_random_seed(SEED)

# %%
test_df = pd.read_csv('test.csv')
train_df = pd.read_csv('train.csv')

# %%
test_df['image_path'] = '/content/images/' + test_df['image_id'] + '.jpg'
train_df['image_path'] = '/content/images/' + train_df['image_id'] + '.jpg'

# %%
n_train = int(len(train_df)*0.8)

# %%
train_gen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_gen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
train_ds = train_gen.flow_from_dataframe(train_df.iloc[:n_train, :],
                                         x_col='image_path',
                                         y_col=TARGET,
                                         class_mode='raw',
                                         batch_size=BATCH_SIZE,
                                         seed=SEED)
val_ds = test_gen.flow_from_dataframe(train_df.iloc[n_train:, :],
                                      x_col='image_path',
                                      y_col=TARGET,
                                      class_mode='raw',
                                      batch_size=BATCH_SIZE,
                                      seed=SEED,
                                      shuffle=False)
test_ds = test_gen.flow_from_dataframe(test_df, x_col='image_path',
                                        class_mode=None,
                                        batch_size=BATCH_SIZE,
                                        seed=SEED,
                                        shuffle=False)
# Out:
# Found 1456 validated image filenames.
# Found 365 validated image filenames.
# Found 1821 validated image filenames.

# %% [markdown]
# # Tuning

# %%
def train_model(lr_tl=0.001, lr_ft=1e-5, drop_rate=0,
                inner_size=(224,224,3), n_epoch=10, fine_tune=False):
    """
    Train parameters of model.

    Args:
        lr_tl: Learning rate for transfer learning.
        model_path: Learning rate for fine tuning.
        drop_rate: Rate of dropout layer.
        inner_size: Size of the inner layer.
        n_epoch: Number of epoches for training.

    Return:
        History of model training.
    """

# Create base model
    base_model = ResNet50(weights='imagenet', input_shape=inner_size, include_top=False)
    base_model.trainable = False
    # Create a new model on top.
    inputs = keras.Input(shape=inner_size)
    x = base_model(inputs, training=False)
    x = keras.layers.GlobalAveragePooling2D()(x)
    x = keras.layers.Dropout(drop_rate)(x)
    outputs = keras.layers.Dense(4, activation='softmax')(x)
    model = keras.Model(inputs, outputs)
    print('====== Strart transfer-learning ======')
    # Transfer-learning train
    model.compile(
                  optimizer=keras.optimizers.Adam(lr_tl),
                  loss=keras.losses.CategoricalCrossentropy(),
                  metrics=[keras.metrics.CategoricalAccuracy()],
                  )
    tl_history = model.fit(train_ds, epochs=n_epoch, validation_data=val_ds)
    if fine_tune:
        print('====== Strart fine-tuning ======')
        # Fine-tuning train
        base_model.trainable=True

        model.compile(
                      optimizer=keras.optimizers.Adam(lr_ft),
                      loss=keras.losses.CategoricalCrossentropy(),
                      metrics=[keras.metrics.CategoricalAccuracy()],
                      )
        fn_history = model.fit(train_ds, epochs=n_epoch, validation_data=val_ds)
        return fn_history
    return tl_history

# %%
def plot_history(history):
    plt.figure(figsize=(18,7))
    plt.subplot(1,2,1)
    plt.plot(history.history['categorical_accuracy'])
    plt.plot(history.history['val_categorical_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    # summarize history for loss
    plt.subplot(1,2,2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %% [markdown]
# ## Tune leraning rate of transfer-learning

# %%
lr_tl_list = [3e-4, 0.001, 0.01]
lr_tune_hist = {}
for lr in lr_tl_list:
    lr_tune_hist[lr] = train_model(lr_tl=lr)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step
# ====== Strart transfer-learning ======
# Epoch 1/10
# 23/23 [==============================] - 76s 3s/step - loss: 1.3526 - categorical_accuracy: 0.3372 - val_loss: 1.1699 - val_categorical_accuracy: 0.4356
# Epoch 2/10
# 23/23 [==============================] - 61s 3s/step - loss: 1.0356 - categorical_accuracy: 0.5735 - val_loss: 0.9493 - val_categorical_accuracy: 0.6521
# Epoch 3/10
# 23/23 [==============================] - 60s 3s/step - loss: 0.8542 - categorical_accuracy: 0.7218 - val_loss: 0.8210 - val_categorical_accuracy: 0.7370
# Epoch 4/10
# 23/23 [==============================] - 58s 3s/step - loss: 0.7482 - categorical_accuracy: 0.7837 - val_loss: 0.7450 - val_categorical_accuracy: 0.7589
# Epoch 5/10
# 23/23 [==============================] - 62s 3s/step - loss: 0.6789 - categorical_accuracy: 0.7995 - val_loss: 0.6920 - val_categorical_accuracy: 0.7863
# Epoch 6/10
# 23/23 [==============================] - 58s 3s/step - loss: 0.6242 - categorical_accuracy: 0.8235 - val_loss: 0.6516 - val_categorical_accuracy: 0.7945
# Epoch 7/10
# 23/23 [==============================] - 58s 3s/step - loss: 0.5828 - categorical_accuracy: 0.8297 - val_loss: 0.6166 - val_categorical_accuracy: 0.8000
# Epoch 8/10
# 23/23 [==============================] - 58s 3s/step - loss: 0.5487 - categorical_accuracy: 0.8386 - val_loss: 0.5894 - val_categorical_accuracy: 0.8219
# Epoch 9/10
# 23/23 [==============================] - 59s 3s/step - loss: 0.5178 - categorical_accuracy: 0.8503 - val_loss: 0.5661 - val_categorical_accuracy: 0.8301
# Epoch 10/10
# 23/23 [==============================] - 60s 3s/step - loss: 0.4948 - categorical_accuracy: 0.8565 - val_loss: 0.5480 - val_categorical_accuracy: 0.8274
# ====== Strart transfer-learning ======
# Epoch 1/10
# Epoch 9/10
# 23/23 [==============================] - 60s 3s/step - loss: 0.0918 - categorical_accuracy: 0.9842 - val_loss: 0.3182 - val_categorical_accuracy: 0.8795
# Epoch 10/10
# 23/23 [==============================] - 58s 3s/step - loss: 0.0806 - categorical_accuracy: 0.9876 - val_loss: 0.3057 - val_categorical_accuracy: 0.8849

# %%
for lr in lr_tune_hist.keys():
  print(f'\t\t\t\t\t\t<<<<<<<< History of model with lr={lr} >>>>>>>>')
  plot_history(lr_tune_hist[lr])
  val_acc = lr_tune_hist[lr].history['val_categorical_accuracy'][-1]
  print(f'Final valid accuracy={round(val_acc, 3)}\n')
# Out:
# 						<<<<<<<< History of model with lr=0.0003 >>>>>>>>
# Final valid accuracy=0.827
#
# 						<<<<<<<< History of model with lr=0.001 >>>>>>>>
# Final valid accuracy=0.874
#
# 						<<<<<<<< History of model with lr=0.01 >>>>>>>>
# Final valid accuracy=0.885

# %% [markdown]
# **Training with leraning rate 0.01 shows best accuracy (0.885).**

# %% [markdown]
# ## Tune leraning rate of fine-tuning.

# %%
lr_ft_list = [3e-6, 1e-5, 1e-4]
fn_tune_hist = {}
for lr in lr_ft_list:
    fn_tune_hist[lr] = train_model(lr_tl=0.01, lr_ft=lr, fine_tune=True)
# Out:
# ====== Strart transfer-learning ======
# Epoch 1/10
# 23/23 [==============================] - 65s 3s/step - loss: 1.2164 - categorical_accuracy: 0.6319 - val_loss: 0.5908 - val_categorical_accuracy: 0.7973
# Epoch 2/10
# 23/23 [==============================] - 59s 3s/step - loss: 0.3942 - categorical_accuracy: 0.8551 - val_loss: 0.4030 - val_categorical_accuracy: 0.8356
# Epoch 3/10
# 23/23 [==============================] - 59s 3s/step - loss: 0.3081 - categorical_accuracy: 0.8887 - val_loss: 0.3856 - val_categorical_accuracy: 0.8630
# Epoch 4/10
# 23/23 [==============================] - 59s 3s/step - loss: 0.2252 - categorical_accuracy: 0.9327 - val_loss: 0.3537 - val_categorical_accuracy: 0.8712
# Epoch 5/10
# 23/23 [==============================] - 63s 3s/step - loss: 0.1818 - categorical_accuracy: 0.9492 - val_loss: 0.3384 - val_categorical_accuracy: 0.8575
# Epoch 6/10
# 23/23 [==============================] - 60s 3s/step - loss: 0.1499 - categorical_accuracy: 0.9567 - val_loss: 0.3113 - val_categorical_accuracy: 0.8877
# Epoch 7/10
# 23/23 [==============================] - 60s 3s/step - loss: 0.1230 - categorical_accuracy: 0.9650 - val_loss: 0.4402 - val_categorical_accuracy: 0.8658
# Epoch 8/10
# 23/23 [==============================] - 61s 3s/step - loss: 0.1207 - categorical_accuracy: 0.9677 - val_loss: 0.3475 - val_categorical_accuracy: 0.8849
# Epoch 9/10
# 23/23 [==============================] - 62s 3s/step - loss: 0.0953 - categorical_accuracy: 0.9808 - val_loss: 0.3227 - val_categorical_accuracy: 0.8822
# Epoch 10/10
# 23/23 [==============================] - 59s 3s/step - loss: 0.2232 - categorical_accuracy: 0.9286 - val_loss: 0.3619 - val_categorical_accuracy: 0.8712
# Epoch 5/10
# 23/23 [==============================] - 62s 3s/step - loss: 0.1972 - categorical_accuracy: 0.9423 - val_loss: 0.3627 - val_categorical_accuracy: 0.8603
# Epoch 6/10
# 23/23 [==============================] - 61s 3s/step - loss: 0.1686 - categorical_accuracy: 0.9547 - val_loss: 0.3347 - val_categorical_accuracy: 0.8603
# Epoch 7/10
# 23/23 [==============================] - 61s 3s/step - loss: 0.1464 - categorical_accuracy: 0.9629 - val_loss: 0.3129 - val_categorical_accuracy: 0.8849
# Epoch 8/10
# 23/23 [==============================] - 62s 3s/step - loss: 0.1234 - categorical_accuracy: 0.9698 - val_loss: 0.3018 - val_categorical_accuracy: 0.8767
# Epoch 9/10
# 23/23 [==============================] - 58s 3s/step - loss: 0.1136 - categorical_accuracy: 0.9746 - val_loss: 0.3433 - val_categorical_accuracy: 0.8740
# Epoch 10/10
# 23/23 [==============================] - 60s 3s/step - loss: 0.0995 - categorical_accuracy: 0.9835 - val_loss: 0.3207 - val_categorical_accuracy: 0.8630
# ====== Strart fine-tuning ======
# Epoch 1/10
# 23/23 [==============================] - 72s 3s/step - loss: 1.8910 - categorical_accuracy: 0.7047 - val_loss: 0.5121 - val_categorical_accuracy: 0.8493
# Epoch 2/10
# 23/23 [==============================] - 65s 3s/step - loss: 0.3490 - categorical_accuracy: 0.8791 - val_loss: 0.2872 - val_categorical_accuracy: 0.9068
# Epoch 3/10
# 23/23 [==============================] - 65s 3s/step - loss: 0.2088 - categorical_accuracy: 0.9286 - val_loss: 0.2729 - val_categorical_accuracy: 0.9014
# Epoch 4/10
# 23/23 [==============================] - 65s 3s/step - loss: 0.1371 - categorical_accuracy: 0.9526 - val_loss: 0.3517 - val_categorical_accuracy: 0.8986
# Epoch 5/10
# 23/23 [==============================] - 67s 3s/step - loss: 0.0896 - categorical_accuracy: 0.9725 - val_loss: 0.2598 - val_categorical_accuracy: 0.9178
# Epoch 6/10
# 23/23 [==============================] - 66s 3s/step - loss: 0.0624 - categorical_accuracy: 0.9801 - val_loss: 0.2849 - val_categorical_accuracy: 0.9068
# Epoch 7/10
# 23/23 [==============================] - 67s 3s/step - loss: 0.0403 - categorical_accuracy: 0.9911 - val_loss: 0.8499 - val_categorical_accuracy: 0.7644
# Epoch 8/10
# 23/23 [==============================] - 65s 3s/step - loss: 0.1155 - categorical_accuracy: 0.9560 - val_loss: 0.3040 - val_categorical_accuracy: 0.9151
# Epoch 9/10
# 23/23 [==============================] - 65s 3s/step - loss: 0.0428 - categorical_accuracy: 0.9883 - val_loss: 0.2390 - val_categorical_accuracy: 0.9260
# Epoch 10/10
# 23/23 [==============================] - 67s 3s/step - loss: 0.0181 - categorical_accuracy: 0.9973 - val_loss: 0.2965 - val_categorical_accuracy: 0.9260

# %%
for lr in fn_tune_hist.keys():
  print(f'\t\t\t\t\t\t<<<<<<<< History of model with lr={lr} >>>>>>>>')
  plot_history(fn_tune_hist[lr])
  val_acc = fn_tune_hist[lr].history['val_categorical_accuracy'][-1]
  print(f'Final valid accuracy={round(val_acc, 3)}\n')
# Out:
# 						<<<<<<<< History of model with lr=3e-06 >>>>>>>>
# Final valid accuracy=0.882
#
# 						<<<<<<<< History of model with lr=1e-05 >>>>>>>>
# Final valid accuracy=0.896
#
# 						<<<<<<<< History of model with lr=0.0001 >>>>>>>>
# Final valid accuracy=0.926

# %% [markdown]
# **Training with leraning rate 0.0001 shows best accuracy (0.926).**

# %% [markdown]
# ## Tune image size

# %%
size_list = [(200,200,3), (224,224,3), (299,299,3)]
size_hist = {}
for size in size_list:
    size_hist[size] = train_model(lr_tl=0.01, lr_ft=1e-4, inner_size=size,
                                  fine_tune=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 5s 0us/step
# ====== Strart transfer-learning ======
# Epoch 1/10
# 23/23 [==============================] - 78s 3s/step - loss: 1.1580 - categorical_accuracy: 0.5893 - val_loss: 0.7670 - val_categorical_accuracy: 0.7068
# Epoch 2/10
# 23/23 [==============================] - 61s 3s/step - loss: 0.6338 - categorical_accuracy: 0.7651 - val_loss: 0.6462 - val_categorical_accuracy: 0.7918
# Epoch 3/10
# 23/23 [==============================] - 61s 3s/step - loss: 0.5272 - categorical_accuracy: 0.8152 - val_loss: 0.5762 - val_categorical_accuracy: 0.8055
# Epoch 4/10
# 23/23 [==============================] - 62s 3s/step - loss: 0.4498 - categorical_accuracy: 0.8379 - val_loss: 0.5529 - val_categorical_accuracy: 0.8137
# Epoch 5/10
# 23/23 [==============================] - 60s 3s/step - loss: 0.4243 - categorical_accuracy: 0.8537 - val_loss: 0.5943 - val_categorical_accuracy: 0.7918
# Epoch 6/10
# 23/23 [==============================] - 60s 3s/step - loss: 0.4424 - categorical_accuracy: 0.8345 - val_loss: 0.7502 - val_categorical_accuracy: 0.7014
# Epoch 7/10
# 23/23 [==============================] - 60s 3s/step - loss: 0.3722 - categorical_accuracy: 0.8688 - val_loss: 0.6088 - val_categorical_accuracy: 0.8164
# Epoch 8/10
# 23/23 [==============================] - 61s 3s/step - loss: 0.3364 - categorical_accuracy: 0.8805 - val_loss: 0.5187 - val_categorical_accuracy: 0.8000
# Epoch 9/10
# 23/23 [==============================] - 62s 3s/step - loss: 0.2840 - categorical_accuracy: 0.8997 - val_loss: 0.5268 - val_categorical_accuracy: 0.8192
# Epoch 10/10
# 23/23 [==============================] - 60s 3s/step - loss: 0.2800 - categorical_accuracy: 0.9052 - val_loss: 0.5632 - val_categorical_accuracy: 0.8137
# ====== Strart fine-tuning ======
# Epoch 1/10
# 23/23 [==============================] - 82s 3s/step - loss: 0.8375 - categorical_accuracy: 0.7301 - val_loss: 0.3953 - val_categorical_accuracy: 0.8603
# Epoch 2/10
# 23/23 [==============================] - 58s 3s/step - loss: 0.4794 - categorical_accuracy: 0.8187 - val_loss: 0.8918 - val_categorical_accuracy: 0.7315
# Epoch 7/10
# 23/23 [==============================] - 59s 3s/step - loss: 0.4048 - categorical_accuracy: 0.8510 - val_loss: 0.5165 - val_categorical_accuracy: 0.8082
# Epoch 8/10
# 23/23 [==============================] - 58s 3s/step - loss: 0.3621 - categorical_accuracy: 0.8688 - val_loss: 0.6616 - val_categorical_accuracy: 0.7726
# Epoch 9/10
# 23/23 [==============================] - 58s 3s/step - loss: 0.3393 - categorical_accuracy: 0.8723 - val_loss: 0.6605 - val_categorical_accuracy: 0.7562
# Epoch 10/10
# 23/23 [==============================] - 58s 3s/step - loss: 0.2997 - categorical_accuracy: 0.8880 - val_loss: 0.5042 - val_categorical_accuracy: 0.8301
# ====== Strart fine-tuning ======
# Epoch 1/10
# 23/23 [==============================] - 77s 3s/step - loss: 0.7701 - categorical_accuracy: 0.7747 - val_loss: 0.3970 - val_categorical_accuracy: 0.8630
# Epoch 2/10
# 23/23 [==============================] - 72s 3s/step - loss: 0.2603 - categorical_accuracy: 0.8997 - val_loss: 0.3300 - val_categorical_accuracy: 0.8630
# Epoch 3/10
# 23/23 [==============================] - 70s 3s/step - loss: 0.0969 - categorical_accuracy: 0.9718 - val_loss: 0.3864 - val_categorical_accuracy: 0.8849
# Epoch 4/10
# 23/23 [==============================] - 70s 3s/step - loss: 0.0224 - categorical_accuracy: 0.9945 - val_loss: 0.3907 - val_categorical_accuracy: 0.8904
# Epoch 5/10
# 23/23 [==============================] - 70s 3s/step - loss: 0.0074 - categorical_accuracy: 0.9993 - val_loss: 0.3753 - val_categorical_accuracy: 0.9014
# Epoch 6/10
# 23/23 [==============================] - 73s 3s/step - loss: 0.0031 - categorical_accuracy: 0.9993 - val_loss: 0.4408 - val_categorical_accuracy: 0.8986
# Epoch 7/10
# 23/23 [==============================] - 71s 3s/step - loss: 0.0048 - categorical_accuracy: 0.9993 - val_loss: 0.4625 - val_categorical_accuracy: 0.9041
# Epoch 8/10
# 23/23 [==============================] - 71s 3s/step - loss: 0.0034 - categorical_accuracy: 0.9986 - val_loss: 0.4697 - val_categorical_accuracy: 0.9096
# Epoch 9/10
# 23/23 [==============================] - 73s 3s/step - loss: 0.0029 - categorical_accuracy: 0.9993 - val_loss: 0.4353 - val_categorical_accuracy: 0.9068
# Epoch 10/10
# 23/23 [==============================] - 71s 3s/step - loss: 0.0016 - categorical_accuracy: 0.9993 - val_loss: 0.4610 - val_categorical_accuracy: 0.9068

# %%
for size in size_hist.keys():
  print(f'\t\t\t\t\t\t<<<<<<<< History of model with size={size} >>>>>>>>')
  plot_history(size_hist[size])
  val_acc = size_hist[size].history['val_categorical_accuracy'][-1]
  print(f'Final valid accuracy={round(val_acc, 3)}\n')
# Out:
# 						<<<<<<<< History of model with size=(150, 150, 3) >>>>>>>>
# Final valid accuracy=0.89
#
# 						<<<<<<<< History of model with size=(256, 256, 3) >>>>>>>>
# Final valid accuracy=0.918
#
# 						<<<<<<<< History of model with size=(299, 299, 3) >>>>>>>>
# Final valid accuracy=0.907

# %% [markdown]
# **Training with inner size (256,256,3) shows best accuracy (0.918).**

# %% [markdown]
# ## Tune Dropout layer rate

# %%
dropout_list = [0, 0.2, 0.4]
dropout_hist = {}
for rate in dropout_list:
    dropout_hist[rate] = train_model(lr_tl=0.01, lr_ft=1e-4, inner_size=(256,256,3),
                                  fine_tune=True)
# Out:
# Epoch 1/10
# 23/23 [==============================] - 64s 3s/step - loss: 1.1460 - categorical_accuracy: 0.6147 - val_loss: 0.9556 - val_categorical_accuracy: 0.6575
# Epoch 2/10
# 23/23 [==============================] - 60s 3s/step - loss: 0.6600 - categorical_accuracy: 0.7603 - val_loss: 0.6375 - val_categorical_accuracy: 0.7836
# Epoch 3/10
# 23/23 [==============================] - 58s 3s/step - loss: 0.5412 - categorical_accuracy: 0.7933 - val_loss: 0.6110 - val_categorical_accuracy: 0.7753
# Epoch 4/10
# 23/23 [==============================] - 58s 3s/step - loss: 0.4477 - categorical_accuracy: 0.8441 - val_loss: 0.5364 - val_categorical_accuracy: 0.8000
# Epoch 5/10
# 23/23 [==============================] - 60s 3s/step - loss: 0.4386 - categorical_accuracy: 0.8420 - val_loss: 0.5623 - val_categorical_accuracy: 0.7945
# Epoch 6/10
# 23/23 [==============================] - 58s 3s/step - loss: 0.3875 - categorical_accuracy: 0.8578 - val_loss: 0.5699 - val_categorical_accuracy: 0.8055
# Epoch 7/10
# 23/23 [==============================] - 58s 3s/step - loss: 0.3585 - categorical_accuracy: 0.8640 - val_loss: 0.5428 - val_categorical_accuracy: 0.8164
# Epoch 8/10
# 23/23 [==============================] - 59s 3s/step - loss: 0.3337 - categorical_accuracy: 0.8819 - val_loss: 0.5104 - val_categorical_accuracy: 0.8356
# Epoch 9/10
# 23/23 [==============================] - 60s 3s/step - loss: 0.3176 - categorical_accuracy: 0.8805 - val_loss: 0.5174 - val_categorical_accuracy: 0.8137
# Epoch 10/10
# 23/23 [==============================] - 59s 3s/step - loss: 0.2878 - categorical_accuracy: 0.9059 - val_loss: 0.5936 - val_categorical_accuracy: 0.7973
# ====== Strart fine-tuning ======
# Epoch 1/10
# 23/23 [==============================] - 78s 3s/step - loss: 0.9474 - categorical_accuracy: 0.7431 - val_loss: 0.4370 - val_categorical_accuracy: 0.8630
# Epoch 2/10
# 23/23 [==============================] - 71s 3s/step - loss: 0.2098 - categorical_accuracy: 0.9286 - val_loss: 0.3371 - val_categorical_accuracy: 0.8795
# Epoch 3/10
# 23/23 [==============================] - 73s 3s/step - loss: 0.0452 - categorical_accuracy: 0.9863 - val_loss: 0.4261 - val_categorical_accuracy: 0.8986
# Epoch 4/10
# 23/23 [==============================] - 72s 3s/step - loss: 0.0059 - categorical_accuracy: 0.9993 - val_loss: 0.4612 - val_categorical_accuracy: 0.9041
# Epoch 5/10
# 23/23 [==============================] - 71s 3s/step - loss: 0.0053 - categorical_accuracy: 0.9993 - val_loss: 0.4872 - val_categorical_accuracy: 0.9041
# Epoch 6/10
# 23/23 [==============================] - 72s 3s/step - loss: 0.0050 - categorical_accuracy: 0.9986 - val_loss: 0.4454 - val_categorical_accuracy: 0.9123
# Epoch 7/10
# 23/23 [==============================] - 73s 3s/step - loss: 0.0025 - categorical_accuracy: 0.9993 - val_loss: 0.4861 - val_categorical_accuracy: 0.9014
# Epoch 8/10
# 23/23 [==============================] - 72s 3s/step - loss: 0.0020 - categorical_accuracy: 0.9986 - val_loss: 0.4782 - val_categorical_accuracy: 0.9041
# Epoch 9/10
# 23/23 [==============================] - 72s 3s/step - loss: 0.0016 - categorical_accuracy: 0.9986 - val_loss: 0.4834 - val_categorical_accuracy: 0.9014
# Epoch 10/10
# 23/23 [==============================] - 72s 3s/step - loss: 0.0022 - categorical_accuracy: 0.9993 - val_loss: 0.4948 - val_categorical_accuracy: 0.9041
# ====== Strart transfer-learning ======
# Epoch 1/10
# 23/23 [==============================] - 65s 3s/step - loss: 1.0257 - categorical_accuracy: 0.6016 - val_loss: 0.7813 - val_categorical_accuracy: 0.6877
# Epoch 2/10
# 23/23 [==============================] - 61s 3s/step - loss: 0.6345 - categorical_accuracy: 0.7637 - val_loss: 0.6328 - val_categorical_accuracy: 0.7918
# Epoch 3/10
# 23/23 [==============================] - 60s 3s/step - loss: 0.5367 - categorical_accuracy: 0.8015 - val_loss: 0.5795 - val_categorical_accuracy: 0.7973
# Epoch 4/10
# 23/23 [==============================] - 60s 3s/step - loss: 0.4551 - categorical_accuracy: 0.8352 - val_loss: 0.5682 - val_categorical_accuracy: 0.8110
# Epoch 5/10
# 23/23 [==============================] - 63s 3s/step - loss: 0.4187 - categorical_accuracy: 0.8441 - val_loss: 0.6145 - val_categorical_accuracy: 0.7781
# Epoch 6/10
# 23/23 [==============================] - 61s 3s/step - loss: 0.3879 - categorical_accuracy: 0.8620 - val_loss: 0.5325 - val_categorical_accuracy: 0.8411
# Epoch 7/10
# 23/23 [==============================] - 61s 3s/step - loss: 0.3410 - categorical_accuracy: 0.8723 - val_loss: 0.5132 - val_categorical_accuracy: 0.8164
# Epoch 8/10
# 23/23 [==============================] - 60s 3s/step - loss: 0.3119 - categorical_accuracy: 0.8949 - val_loss: 0.5664 - val_categorical_accuracy: 0.8082
# Epoch 9/10
# 23/23 [==============================] - 60s 3s/step - loss: 0.2967 - categorical_accuracy: 0.8997 - val_loss: 0.5472 - val_categorical_accuracy: 0.8219
# Epoch 10/10
# 23/23 [==============================] - 62s 3s/step - loss: 0.2709 - categorical_accuracy: 0.9087 - val_loss: 0.5108 - val_categorical_accuracy: 0.8438
# ====== Strart fine-tuning ======
# Epoch 1/10
# 23/23 [==============================] - 78s 3s/step - loss: 0.6588 - categorical_accuracy: 0.7864 - val_loss: 0.3793 - val_categorical_accuracy: 0.8795
# Epoch 9/10
# 23/23 [==============================] - 60s 3s/step - loss: 0.3217 - categorical_accuracy: 0.8894 - val_loss: 0.5004 - val_categorical_accuracy: 0.8329
# Epoch 10/10
# 23/23 [==============================] - 60s 3s/step - loss: 0.2974 - categorical_accuracy: 0.9052 - val_loss: 0.4797 - val_categorical_accuracy: 0.8329
# ====== Strart fine-tuning ======
# Epoch 1/10
# 23/23 [==============================] - 80s 3s/step - loss: 0.8358 - categorical_accuracy: 0.7651 - val_loss: 0.4172 - val_categorical_accuracy: 0.8466
# Epoch 2/10
# 23/23 [==============================] - 72s 3s/step - loss: 0.2281 - categorical_accuracy: 0.9258 - val_loss: 0.3603 - val_categorical_accuracy: 0.8685
# Epoch 3/10
# 23/23 [==============================] - 72s 3s/step - loss: 0.0735 - categorical_accuracy: 0.9766 - val_loss: 0.3507 - val_categorical_accuracy: 0.8959
# Epoch 4/10
# 23/23 [==============================] - 72s 3s/step - loss: 0.0242 - categorical_accuracy: 0.9959 - val_loss: 0.4053 - val_categorical_accuracy: 0.8795
# Epoch 5/10
# 23/23 [==============================] - 72s 3s/step - loss: 0.0047 - categorical_accuracy: 0.9986 - val_loss: 0.4296 - val_categorical_accuracy: 0.8959
# Epoch 6/10
# 23/23 [==============================] - 73s 3s/step - loss: 0.0064 - categorical_accuracy: 0.9993 - val_loss: 0.4686 - val_categorical_accuracy: 0.8986
# Epoch 7/10
# 23/23 [==============================] - 71s 3s/step - loss: 0.0030 - categorical_accuracy: 0.9993 - val_loss: 0.4481 - val_categorical_accuracy: 0.8959
# Epoch 8/10
# 23/23 [==============================] - 71s 3s/step - loss: 0.0050 - categorical_accuracy: 0.9986 - val_loss: 0.4507 - val_categorical_accuracy: 0.9068
# Epoch 9/10
# 23/23 [==============================] - 71s 3s/step - loss: 0.0027 - categorical_accuracy: 0.9986 - val_loss: 0.4629 - val_categorical_accuracy: 0.9068
# Epoch 10/10
# 23/23 [==============================] - 72s 3s/step - loss: 0.0019 - categorical_accuracy: 0.9993 - val_loss: 0.4841 - val_categorical_accuracy: 0.9014

# %%
for rate in dropout_hist.keys():
  print(f'\t\t\t\t\t\t<<<<<<<< History of model with size={rate} >>>>>>>>')
  plot_history(dropout_hist[rate])
  val_acc = dropout_hist[rate].history['val_categorical_accuracy'][-1]
  print(f'Final valid accuracy={round(val_acc, 3)}\n')
# Out:
# 						<<<<<<<< History of model with size=0 >>>>>>>>
# Final valid accuracy=0.904
#
# 						<<<<<<<< History of model with size=0.2 >>>>>>>>
# Final valid accuracy=0.923
#
# 						<<<<<<<< History of model with size=0.4 >>>>>>>>
# Final valid accuracy=0.901

# %% [markdown]
# **Training with dropout rate 0.2 shows best accuracy (0.923).**

# %% [markdown]
# ## Inference

# %% [markdown]
# Best parameters:
#
# *   learning rate for transfer-learning: 0.01
# *   learning rate for fine-tuning: 0.0001
# *   inner size: (256, 256, 3)
# *   dropout rate: 0.2
#
# Best val accuracy: 0.923
